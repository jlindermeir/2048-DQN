# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from time import time
import pprint
pp = pprint.PrettyPrinter(indent=4)
# %matplotlib inline

from games import x2048
from agents import DQNagent
plt.rcParams['figure.figsize'] = [15, 10]
# Out:
# Using TensorFlow backend.

# %%
class paramgen():
    def __init__(self, hyp_ranges):
        self.range_list = hyp_ranges
    def __iter__(self):
        return self
    def __next__(self):
        randset = []
        for rang in self.range_list:
            if rang[1]:
                randset.append(np.random.normal(loc=rang[0], scale=rang[1]))
            else:
                randset.append(rang[0])
        return randset

# %%
dim = 2
n_sets = 128
episodes = 3000

set_decay = 0.5
sigma_decay = 0.66

hyp_ranges = [
    #'learning rate':
    (0.01, 0.02),
    #'batch size':
    (32, 0),
    #'eps settings':
    (1.0, 0.1), #eps0
    (0.01, .0001), #epsmin 
    (0.995, 0.2), #epsdecay
    #'gamma':
    (0.8, 0.1),
    #'memory length':
    (2000, 0)
]

game = x2048(dim)
gen = paramgen(hyp_ranges)

t_scorearr = []
m_scorearr = []
err_scorearr = []

arrs = []
f_arrs = []

# %%
j = 0
max_score = 0
max_params = None
c_sets = n_sets
c_hype_ranges = hyp_ranges

while np.floor(c_sets)>=1:
    time_0s = time()
    gen = paramgen(c_hype_ranges)
    
    for i, paramset in enumerate(gen):
        time0 = time()
        agent = DQNagent(game, paramset)
        agent.disableGPU()
        sarr = agent.train(episodes = episodes, savedir='data')[0]

        time1 = time()
        arrs.append(sarr)
        sarr_filtered = gaussian_filter(sarr, 100)
        f_arrs.append(sarr_filtered)
        i_max = np.argmax(sarr_filtered)
        l_file = 'data/eps%i.h5' % i_max
        print(l_file, ' loaded.')
        agent.model = agent.cModel(file=l_file)
        score = agent.eval(500)[0]

        time2 = time()
        print("%i/%i done, t-train:%i, t_eval:%i, t_total:%i" % (i+1, c_sets, time1-time0, time2-time1, time2-time0))
        if score > max_score:
            max_score = score
            max_params = paramset
        print('%sS: AVG: %f @ %i'  % ('New max score! ' if score==max_score else '', score, i_max))
        print(paramset)    
        print()
        if i+1 == c_sets: break
        
    c_hype_ranges = [(mean, hyp_ranges[i][1]) for i,mean in enumerate(max_params)]
    c_sets *= 0.5
    time_1s = time()
    print('Iteration %i done! S: %f T: %f' % (j,max_score, time_1s - time_0s))
    pp.pprint(c_hype_ranges)
    j+=1
    print('#'*33)
# Out:
# WARNING:tensorflow:From /home/menschmeir/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/menschmeir/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Training done!
# data/eps1438.h5  loaded.
# Evaluation done!
# 1/128 done, t-train:96, t_eval:2, t_total:98
# New max score! S: AVG: 22.856000 @ 1438
# [-0.0024052391239048794, 32, 0.9576670336060975, 0.009994771331769863, 1.1551029799036394, 0.7072397256867595, 2000]
#
# Training done!
# data/eps1897.h5  loaded.
# Evaluation done!
# 2/128 done, t-train:102, t_eval:2, t_total:105
# S: AVG: 21.712000 @ 1897
# [-0.020997391493189452, 32, 1.0837465759363945, 0.00999762592067113, 1.0361179845647677, 0.8898052472403291, 2000]
#
# Training done!
# data/eps2404.h5  loaded.
# Evaluation done!
# 3/128 done, t-train:107, t_eval:3, t_total:111
# S: AVG: 21.824000 @ 2404
# [-0.0035448824887519773, 32, 1.0777946997726184, 0.010025997264544175, 0.9991218105592153, 0.8039387545030509, 2000]
#
# Training done!
# data/eps2771.h5  loaded.
# Evaluation done!
# 4/128 done, t-train:115, t_eval:3, t_total:119
# New max score! S: AVG: 27.096000 @ 2771
# [-0.0042084966244534255, 32, 0.9765231524293794, 0.009826072144996721, 1.1785389083446, 0.7534306113161451, 2000]
#
# Training done!
# data/eps232.h5  loaded.
# Evaluation done!
# 5/128 done, t-train:117, t_eval:3, t_total:120
# S: AVG: 11.216000 @ 232
# [-0.00839833581648781, 32, 0.8810715376773457, 0.010023645840851034, 1.3275080741745717, 0.8582342724118694, 2000]
#
# Training done!
# data/eps2336.h5  loaded.
# Evaluation done!
# 6/128 done, t-train:141, t_eval:6, t_total:147
# New max score! S: AVG: 56.032000 @ 2336
# [0.024945753147661294, 32, 0.8807764059120765, 0.009874009248610687, 0.8157257216896409, 0.6329266320244783, 2000]
#
# Training done!
# data/eps1437.h5  loaded.
# Evaluation done!
# 7/128 done, t-train:138, t_eval:4, t_total:143
# S: AVG: 22.912000 @ 1437
# [-0.0005911332969916056, 32, 0.9681201257009668, 0.010022833789802477, 0.9346261543993106, 0.7595626821725593, 2000]
#
# Training done!
# data/eps2462.h5  loaded.
# Evaluation done!
# 8/128 done, t-train:143, t_eval:5, t_total:149
# S: AVG: 41.648000 @ 2462
# [-0.014784424842696256, 32, 1.0443507361195414, 0.01010841674194657, 1.288606941710555, 0.7546735135997185, 2000]
#
# Training done!
# data/eps1522.h5  loaded.
# Evaluation done!
# 9/128 done, t-train:155, t_eval:5, t_total:160
# S: AVG: 25.976000 @ 1522
# [0.0282179782858505, 32, 0.8921282696669404, 0.010105929926940208, 0.9968796913366369, 0.8066027506035021, 2000]
#
# Training done!
# data/eps625.h5  loaded.
# Evaluation done!
# 10/128 done, t-train:171, t_eval:7, t_total:179
# New max score! S: AVG: 61.448000 @ 625
# [0.004222167688365399, 32, 0.9493531990652965, 0.009981330601012878, 0.7647378360181458, 0.7356767432864995, 2000]
#
# Training done!
# data/eps390.h5  loaded.
# Evaluation done!
# 11/128 done, t-train:160, t_eval:5, t_total:165
# S: AVG: 21.120000 @ 390
# [-0.004575297889344193, 32, 0.9683054404190449, 0.009993651159483027, 0.924065716687034, 0.8738832602440444, 2000]
#
# Training done!
# data/eps2868.h5  loaded.
# Evaluation done!
# 12/128 done, t-train:170, t_eval:7, t_total:178
# S: AVG: 53.264000 @ 2868
# [0.01847496625243607, 32, 0.9507066953618926, 0.009909397282822922, 1.2585346732686966, 0.8445110482322937, 2000]
#
# Training done!
# data/eps1874.h5  loaded.
# Evaluation done!
# 13/128 done, t-train:189, t_eval:9, t_total:198
# New max score! S: AVG: 64.040000 @ 1874
# [0.006581198371673891, 32, 0.9535509558172901, 0.010042335525602351, 0.89252411502471, 0.7936843965930348, 2000]
#
# Training done!
# data/eps1685.h5  loaded.
# Evaluation done!
# 14/128 done, t-train:177, t_eval:7, t_total:185
# S: AVG: 40.680000 @ 1685
# [0.007817278984976882, 32, 0.894882797062464, 0.009993747698451683, 1.3368346302235359, 0.9112740362052465, 2000]
#
# Training done!
# data/eps2176.h5  loaded.
# Evaluation done!
# 15/128 done, t-train:187, t_eval:6, t_total:194
# S: AVG: 20.792000 @ 2176
# [-0.020993090805312746, 32, 1.0579016592217778, 0.009991105758620075, 0.7533422857113848, 0.5548079327647731, 2000]
#
# Training done!
# data/eps2259.h5  loaded.
# Evaluation done!
# 16/128 done, t-train:197, t_eval:7, t_total:204
# S: AVG: 27.216000 @ 2259
# [0.047297194438939365, 32, 0.9110196721247394, 0.009971193549506483, 0.8154513542312266, 0.7840880725646104, 2000]
#
# Training done!
# data/eps256.h5  loaded.
# Evaluation done!
# 17/128 done, t-train:196, t_eval:7, t_total:203
# S: AVG: 19.304000 @ 256
# [-0.0033725843286087943, 32, 0.7707046466164814, 0.009895102446043554, 0.9949232885237015, 0.808676027425095, 2000]
#
# Training done!
# data/eps2105.h5  loaded.
# Evaluation done!
# 18/128 done, t-train:209, t_eval:9, t_total:219
# S: AVG: 43.960000 @ 2105
# [0.0431245105422036, 32, 1.0913045127354901, 0.010020516343803638, 0.7729415482400768, 0.6263689272172641, 2000]
#
# Training done!
# data/eps1174.h5  loaded.
# Evaluation done!
# 19/128 done, t-train:215, t_eval:8, t_total:224
# S: AVG: 28.080000 @ 1174
# [-0.002718711488551904, 32, 0.8479007038492583, 0.010145775431079466, 0.6509405162190508, 0.8799032045695011, 2000]
#
# Training done!
# data/eps2834.h5  loaded.
# Evaluation done!
# 20/128 done, t-train:220, t_eval:10, t_total:231
# S: AVG: 57.528000 @ 2834
# [0.007179691392336355, 32, 0.9945498596212579, 0.009965310968877254, 1.1890342218556613, 0.7028477581790973, 2000]
#
# Training done!
# data/eps1053.h5  loaded.
# Evaluation done!
# 21/128 done, t-train:220, t_eval:9, t_total:229
# S: AVG: 21.872000 @ 1053
# [-0.008834190709043234, 32, 1.0301476128632319, 0.009999815202564313, 0.8408191587256524, 0.7788246514819899, 2000]
#
# Training done!
# data/eps748.h5  loaded.
# Evaluation done!
# 22/128 done, t-train:225, t_eval:9, t_total:235
# S: AVG: 21.768000 @ 748
# [-0.02075587531777654, 32, 1.142698277084201, 0.010098340966434825, 0.8115291807026146, 1.0474403148385185, 2000]
#
# Training done!
# data/eps1844.h5  loaded.
# Evaluation done!
# 23/128 done, t-train:228, t_eval:11, t_total:239
# S: AVG: 42.592000 @ 1844
# [0.01527716805074487, 32, 0.9967907685548715, 0.009984506184751281, 1.1871817752415168, 0.7635512737908899, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 24/128 done, t-train:250, t_eval:13, t_total:263
# S: AVG: 63.496000 @ 2999
# [0.01573741394787706, 32, 1.015433705909505, 0.010056805209804363, 0.8006069348205925, 0.7900872666691174, 2000]
#
# Training done!
# data/eps2487.h5  loaded.
# Evaluation done!
# 25/128 done, t-train:234, t_eval:12, t_total:246
# S: AVG: 46.272000 @ 2487
# [0.031004321483812373, 32, 0.9688701021888421, 0.010019934329624352, 1.0478164724391779, 0.7566837571040391, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 26/128 done, t-train:246, t_eval:11, t_total:257
# S: AVG: 22.976000 @ 2999
# [-0.0026737774342380366, 32, 1.0187730275471425, 0.009906338009820414, 0.8192477783816234, 0.7858954497042766, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 27/128 done, t-train:251, t_eval:12, t_total:263
# S: AVG: 37.136000 @ 2999
# [0.01177654467874567, 32, 0.7055470238475336, 0.009934111116220442, 1.3377103897898226, 0.7402501299019676, 2000]
# Training done!
# data/eps690.h5  loaded.
# Evaluation done!
# 28/128 done, t-train:268, t_eval:12, t_total:280
# S: AVG: 33.320000 @ 690
# [-0.0033390858500344425, 32, 0.8046059580075673, 0.01006714664639432, 0.6165305152755456, 0.8327498406286177, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 29/128 done, t-train:285, t_eval:15, t_total:300
# S: AVG: 52.496000 @ 2999
# [0.0037736162399090436, 32, 1.0364441422214057, 0.009861622262034044, 0.9869020325242598, 0.8113460006883476, 2000]
#
# Training done!
# data/eps869.h5  loaded.
# Evaluation done!
# 30/128 done, t-train:273, t_eval:16, t_total:290
# S: AVG: 59.848000 @ 869
# [0.026617564881834754, 32, 1.12381215013149, 0.010018949945086354, 0.5979825644276148, 0.778464297081743, 2000]
#
# Training done!
# data/eps2270.h5  loaded.
# Evaluation done!
# 31/128 done, t-train:272, t_eval:13, t_total:285
# S: AVG: 21.944000 @ 2270
# [0.01793817742111426, 32, 1.0370983333925252, 0.010013736802594613, 1.0721468074581813, 0.8295337449824097, 2000]
#
# Training done!
# data/eps1636.h5  loaded.
# Evaluation done!
# 32/128 done, t-train:306, t_eval:17, t_total:324
# New max score! S: AVG: 66.136000 @ 1636
# [0.018475833297026907, 32, 1.0422976191744806, 0.01004094190643251, 0.9321695683282285, 0.7401548160727724, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 33/128 done, t-train:273, t_eval:12, t_total:286
# S: AVG: 12.928000 @ 2999
# [-0.020823194863247137, 32, 0.9856185244491493, 0.009914966891057274, 0.8096437367413198, 0.8777334079562329, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 34/128 done, t-train:303, t_eval:18, t_total:321
# S: AVG: 63.368000 @ 2999
# [0.03779476683413025, 32, 1.0959963318774801, 0.010128725161601758, 0.8384146222090594, 0.7406774507824301, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 35/128 done, t-train:304, t_eval:18, t_total:322
# S: AVG: 63.080000 @ 2999
# [0.013433068400730327, 32, 1.1368694245379851, 0.009969039924321844, 1.3964499839210855, 0.6178281358670848, 2000]
#
# Training done!
# data/eps2052.h5  loaded.
# Evaluation done!
# 36/128 done, t-train:314, t_eval:17, t_total:332
# S: AVG: 50.512000 @ 2052
# [0.03181230736315151, 32, 1.1575155161747364, 0.010089227283147907, 0.5769537906025017, 0.649566780975188, 2000]
#
# Training done!
# data/eps1009.h5  loaded.
# Evaluation done!
# 37/128 done, t-train:306, t_eval:15, t_total:322
# S: AVG: 21.408000 @ 1009
# [-0.026311353637160417, 32, 0.8492284169069888, 0.0101457135429132, 0.9796363602564037, 0.8849841498325487, 2000]
#
# Training done!
# data/eps1769.h5  loaded.
# Evaluation done!
# 38/128 done, t-train:316, t_eval:19, t_total:336
# S: AVG: 53.184000 @ 1769
# [0.0132435577046585, 32, 0.8688132452348947, 0.010061996048301783, 0.9679808518264109, 0.9939284901939714, 2000]
#
# Training done!
# data/eps2709.h5  loaded.
# Evaluation done!
# 39/128 done, t-train:322, t_eval:20, t_total:342
# S: AVG: 61.616000 @ 2709
# [0.008353903940606037, 32, 1.0322164168750423, 0.010183666801637622, 1.1382285490919397, 0.772580168929307, 2000]
#
# Training done!
# data/eps1855.h5  loaded.
# Evaluation done!
# 40/128 done, t-train:326, t_eval:19, t_total:346
# S: AVG: 43.848000 @ 1855
# [0.0350824559940526, 32, 0.9259606852816203, 0.009997321743271483, 0.7093110663550254, 0.8258431812148488, 2000]
#
# Training done!
# data/eps2601.h5  loaded.
# Evaluation done!
# 41/128 done, t-train:347, t_eval:22, t_total:369
# S: AVG: 65.776000 @ 2601
# [0.020005710433529684, 32, 1.1061215522418055, 0.009740939911440018, 0.9702593318459518, 0.7854257301352552, 2000]
#
# Training done!
# data/eps1342.h5  loaded.
# Evaluation done!
# 42/128 done, t-train:325, t_eval:17, t_total:343
# S: AVG: 21.776000 @ 1342
# [-0.010341042886461297, 32, 0.9708945737774273, 0.009935176610448295, 1.0278663241964958, 0.8718665382352665, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 43/128 done, t-train:335, t_eval:20, t_total:355
# S: AVG: 39.160000 @ 2999
# [0.012532979922738512, 32, 0.9649979437432776, 0.010061076909329473, 1.2002476761165053, 0.8816803589776683, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 44/128 done, t-train:356, t_eval:23, t_total:380
# S: AVG: 62.072000 @ 2999
# [0.0060547671307787775, 32, 0.8482244264773883, 0.0099560482116506, 0.8967481538637438, 0.7604804952245643, 2000]
#
# Training done!
# data/eps2667.h5  loaded.
# Evaluation done!
# 45/128 done, t-train:350, t_eval:22, t_total:372
# S: AVG: 44.688000 @ 2667
# [0.023151041923129494, 32, 0.9748871846643778, 0.010021095963015682, 0.9190106209771338, 0.7787733144675374, 2000]
#
# Training done!
# data/eps1360.h5  loaded.
# Evaluation done!
# 46/128 done, t-train:342, t_eval:20, t_total:362
# S: AVG: 21.736000 @ 1360
# [-0.01489564801778292, 32, 1.08683297218505, 0.009884917058820684, 1.0776995739389954, 0.6294348214433545, 2000]
#
# Training done!
# data/eps2826.h5  loaded.
# Evaluation done!
# 47/128 done, t-train:350, t_eval:21, t_total:371
# S: AVG: 36.016000 @ 2826
# [0.03230313427509108, 32, 0.9003443776136245, 0.00998267499953854, 1.027632481470404, 0.745865596700618, 2000]
#
# Training done!
# data/eps2519.h5  loaded.
# Evaluation done!
# 48/128 done, t-train:354, t_eval:21, t_total:376
# S: AVG: 26.288000 @ 2519
# [0.03472311182628016, 32, 0.8612455029652075, 0.010043486416916757, 1.1188852877251372, 0.9018840060543175, 2000]
#
# Training done!
# data/eps874.h5  loaded.
# Evaluation done!
# 49/128 done, t-train:371, t_eval:24, t_total:395
# S: AVG: 42.952000 @ 874
# [0.017518583357515775, 32, 1.0521407010567327, 0.010009476377661627, 0.9160949076269969, 0.8228253604330624, 2000]
#
# Training done!
# data/eps2759.h5  loaded.
# Evaluation done!
# 50/128 done, t-train:379, t_eval:26, t_total:405
# S: AVG: 62.224000 @ 2759
# [0.008912961567693245, 32, 1.1217237008749361, 0.009891297712338647, 1.3090060407986521, 0.6508367940225058, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 51/128 done, t-train:374, t_eval:25, t_total:400
# S: AVG: 50.752000 @ 2999
# [0.025379450582666864, 32, 0.9993406348264465, 0.009920367797420102, 1.3246618032209203, 0.6706768056892284, 2000]
#
# Training done!
# data/eps2643.h5  loaded.
# Evaluation done!
# 52/128 done, t-train:381, t_eval:26, t_total:407
# S: AVG: 52.384000 @ 2643
# [0.0023309561963970084, 32, 1.1997382623563786, 0.010034704411017031, 1.2777482927853185, 0.9396675517809421, 2000]
#
# Training done!
# data/eps2792.h5  loaded.
# Evaluation done!
# 53/128 done, t-train:391, t_eval:25, t_total:416
# S: AVG: 34.416000 @ 2792
# [0.009515053485592779, 32, 1.037757413388182, 0.00996754463427178, 0.7870522867025895, 0.9384064534490061, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 54/128 done, t-train:380, t_eval:24, t_total:404
# S: AVG: 24.000000 @ 2999
# [-0.008851208542892964, 32, 0.963424183053795, 0.010139146934100608, 1.3446543804935085, 0.7958515413767862, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 55/128 done, t-train:392, t_eval:26, t_total:419
# S: AVG: 43.160000 @ 2999
# [0.014006022564724895, 32, 1.0123672725985713, 0.009952128227012923, 1.102156304153758, 0.7711479363028251, 2000]
#
# Training done!
# data/eps1838.h5  loaded.
# Evaluation done!
# 56/128 done, t-train:428, t_eval:30, t_total:459
# S: AVG: 65.520000 @ 1838
# [0.005469996684975292, 32, 0.9904030448354137, 0.009850724536781904, 0.7378512972919955, 0.8828469759068782, 2000]
# Training done!
# data/eps2577.h5  loaded.
# Evaluation done!
# 57/128 done, t-train:406, t_eval:30, t_total:436
# S: AVG: 57.944000 @ 2577
# [0.02419162647228167, 32, 0.9809967331663517, 0.009980880340075044, 1.1373527731076678, 0.7855834698923186, 2000]
#
# Training done!
# data/eps1091.h5  loaded.
# Evaluation done!
# 58/128 done, t-train:414, t_eval:30, t_total:445
# S: AVG: 54.576000 @ 1091
# [0.030272136496181774, 32, 0.9914047117020274, 0.01004850390447653, 0.7761306091218687, 0.8979846911903164, 2000]
#
# Training done!
# data/eps2573.h5  loaded.
# Evaluation done!
# 59/128 done, t-train:407, t_eval:28, t_total:435
# S: AVG: 35.088000 @ 2573
# [0.02569909745616606, 32, 1.0115673142863812, 0.010034246243619071, 1.5219553870118934, 0.7868701212256718, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 60/128 done, t-train:418, t_eval:27, t_total:446
# S: AVG: 23.512000 @ 2999
# [-0.00352876913432653, 32, 0.873096598312623, 0.009983581988283112, 0.9758949001213878, 0.7335181628329577, 2000]
#
# Training done!
# data/eps1320.h5  loaded.
# Evaluation done!
# 61/128 done, t-train:449, t_eval:34, t_total:483
# New max score! S: AVG: 67.392000 @ 1320
# [0.013789482254543675, 32, 1.1827441119418947, 0.010043847676676102, 0.7447212942406423, 0.8348185066787255, 2000]
#
# Training done!
# data/eps1632.h5  loaded.
# Evaluation done!
# 62/128 done, t-train:416, t_eval:28, t_total:444
# S: AVG: 21.496000 @ 1632
# [-0.018191683679111934, 32, 1.104930308043207, 0.010079522132440885, 1.0975374182330626, 0.6228281249503369, 2000]
#
# Training done!
# data/eps495.h5  loaded.
# Evaluation done!
# 63/128 done, t-train:415, t_eval:28, t_total:443
# S: AVG: 15.992000 @ 495
# [-0.008150882653301517, 32, 1.1681320205765802, 0.010008603041919115, 1.1134229514397709, 0.7630768571989698, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 64/128 done, t-train:449, t_eval:34, t_total:484
# S: AVG: 62.952000 @ 2999
# [0.0070600304629332596, 32, 1.2093039374055026, 0.010138294523671784, 1.0347952983104967, 0.7113858776220029, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 65/128 done, t-train:442, t_eval:30, t_total:472
# S: AVG: 21.096000 @ 2999
# [-0.0032834545125696325, 32, 0.9486183486137316, 0.009978866290972215, 0.9177082762194889, 0.8030949054407076, 2000]
#
# Training done!
# data/eps840.h5  loaded.
# Evaluation done!
# 66/128 done, t-train:449, t_eval:32, t_total:481
# S: AVG: 33.184000 @ 840
# [0.018576743170740415, 32, 0.9027887964767134, 0.00987681981331454, 0.9071827411512425, 0.899652473158901, 2000]
#
# Training done!
# data/eps0.h5  loaded.
# Evaluation done!
# 67/128 done, t-train:435, t_eval:22, t_total:457
# S: AVG: 16.072000 @ 0
# [-0.012966022175494097, 32, 0.9617766969210227, 0.010025525574826626, 1.074911416326263, 0.6479801857625126, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 68/128 done, t-train:457, t_eval:36, t_total:494
# S: AVG: 59.776000 @ 2999
# [0.005810498742067975, 32, 0.9994158730030074, 0.010044250677937223, 1.2817543287830848, 0.8663694951791737, 2000]
#
# Training done!
# data/eps0.h5  loaded.
# Evaluation done!
# 69/128 done, t-train:464, t_eval:24, t_total:489
# S: AVG: 23.680000 @ 0
# [-0.008043178882394515, 32, 1.09443528206069, 0.009976721664259653, 0.9059678768491766, 0.7066039855288383, 2000]
#
# Training done!
# data/eps1907.h5  loaded.
# Evaluation done!
# 70/128 done, t-train:448, t_eval:31, t_total:479
# S: AVG: 15.376000 @ 1907
# [-0.0005075391718437974, 32, 0.978482832279722, 0.009951361912306332, 0.7447736103830416, 0.9966953260366892, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 71/128 done, t-train:479, t_eval:39, t_total:518
# S: AVG: 58.344000 @ 2999
# [0.005361976061888053, 32, 0.9375084276929617, 0.009998032466893122, 1.0015155747265996, 0.8084833256435925, 2000]
#
# Training done!
# data/eps2770.h5  loaded.
# Evaluation done!
# 72/128 done, t-train:472, t_eval:36, t_total:509
# S: AVG: 40.872000 @ 2770
# [0.04641516462045923, 32, 0.9996581280362292, 0.009946764169397557, 1.1889225847354763, 0.66677928284254, 2000]
#
# Training done!
# data/eps2040.h5  loaded.
# Evaluation done!
# 73/128 done, t-train:466, t_eval:34, t_total:500
# S: AVG: 21.024000 @ 2040
# [-0.004232260045515029, 32, 1.1450520249948823, 0.010131422544503577, 1.1429039085583184, 0.8053001037762413, 2000]
#
# Training done!
# data/eps2891.h5  loaded.
# Evaluation done!
# 74/128 done, t-train:487, t_eval:40, t_total:527
# S: AVG: 58.776000 @ 2891
# [0.005829631475519633, 32, 0.8517651095406732, 0.009974654713915414, 1.059520859547471, 0.8929745861685503, 2000]
#
# Training done!
# data/eps2634.h5  loaded.
# Evaluation done!
# 75/128 done, t-train:477, t_eval:35, t_total:513
# S: AVG: 25.480000 @ 2634
# [-0.000124660633968399, 32, 0.9385772624480362, 0.010126188092546807, 1.0732137282719552, 0.741723626587401, 2000]
#
# Training done!
# data/eps2858.h5  loaded.
# Evaluation done!
# 76/128 done, t-train:482, t_eval:36, t_total:519
# S: AVG: 22.464000 @ 2858
# [-0.01862317076241915, 32, 0.9267256185084783, 0.009985206170587804, 1.1372340788499282, 0.9750914018704193, 2000]
#
# Training done!
# data/eps572.h5  loaded.
# Evaluation done!
# 77/128 done, t-train:502, t_eval:40, t_total:543
# S: AVG: 49.808000 @ 572
# [0.015296254169982013, 32, 0.8671881766274491, 0.010020228161560328, 0.8208706090130413, 0.8697182604381413, 2000]
#
# Training done!
# data/eps2419.h5  loaded.
# Evaluation done!
# 78/128 done, t-train:544, t_eval:44, t_total:589
# S: AVG: 66.680000 @ 2419
# [0.007146658712154716, 32, 0.9032737454533091, 0.010040410140150967, 0.889939798245647, 0.7752944973209918, 2000]
#
# Training done!
# data/eps1064.h5  loaded.
# Evaluation done!
# 79/128 done, t-train:522, t_eval:41, t_total:564
# S: AVG: 48.152000 @ 1064
# [0.027192689688056902, 32, 0.9965774415428829, 0.009983963331963863, 0.9708016722259126, 0.7503111965650637, 2000]
#
# Training done!
# data/eps963.h5  loaded.
# Evaluation done!
# 80/128 done, t-train:502, t_eval:38, t_total:541
# S: AVG: 22.432000 @ 963
# [0.022898308087821277, 32, 1.0115304819363509, 0.010062887893221545, 1.1132727257824933, 0.9407643111892805, 2000]
#
# Training done!
# data/eps2999.h5  loaded.
# Evaluation done!
# 81/128 done, t-train:530, t_eval:45, t_total:575
# S: AVG: 62.864000 @ 2999
# [0.0013542242971713546, 32, 0.9347148225246724, 0.010025289195527757, 1.1156524401301793, 0.7965558739625058, 2000]
#
# Training done!
# data/eps2714.h5  loaded.
# Evaluation done!
# 82/128 done, t-train:528, t_eval:41, t_total:569
# S: AVG: 32.936000 @ 2714
# [0.041571718909761635, 32, 1.0297531487173557, 0.010003483431981429, 0.9527153584543748, 0.8628542345173854, 2000]
#
# Training done!
# data/eps2953.h5  loaded.
# Evaluation done!
# 83/128 done, t-train:535, t_eval:45, t_total:580
# S: AVG: 56.336000 @ 2953
# [0.013719473343640763, 32, 1.217673373325823, 0.010078456591100389, 1.1706905941462065, 0.6776489280981877, 2000]
#
# Training done!
# data/eps0.h5  loaded.
# Evaluation done!
# 84/128 done, t-train:508, t_eval:28, t_total:537
# S: AVG: 11.032000 @ 0
# [-0.0113649358789939, 32, 0.9368252381278517, 0.010170715669235261, 0.8644635360889313, 0.8019032829402635, 2000]
#
# Training episode 1201/3000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-807527b0741b> in <module>
#      13         agent = DQNagent(game, paramset)
#      14         agent.disableGPU()
# ---> 15         sarr = agent.train(episodes = episodes, savedir='data')[0]
#      16
#      17         time1 = time()
#
# ~/Documents/2048-DQN/agents.py in train(self, episodes, savedir)
#     166             if savedir: self.model.save('%s/eps%i.h5' % (savedir, i))
#     167             if len(self.memory) > self.batch_size:
# --> 168                 self.replay()
#     169         time1 = time()
#     170         avgtime = (time1/time0)/episodes
#
# ~/Documents/2048-DQN/agents.py in replay(self)
#     101             else:
#     102                 target = reward + self.gamma * np.amax(self.model.predict(self.pad(next_state))[0])
# --> 103             target_f = self.model.predict(self.pad(state))
#     104             target_f[0][action] = target
#     105             x_batch.append(state.flatten())
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2695
#    2696     def __call__(self, inputs):
# -> 2697         if hasattr(get_session(), '_make_callable_from_options'):
#    2698             if py_any(is_sparse(x) for x in self.inputs):
#    2699                 if py_any(is_tensor(x) for x in inputs):
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     191             candidate_vars = []
#     192             for v in variables:
# --> 193                 if not getattr(v, '_keras_initialized', False):
#     194                     candidate_vars.append(v)
#     195             if candidate_vars:
#
# KeyboardInterrupt:

# %%
[0.013789482254543675, 32, 1.1827441119418947, 0.010043847676676102, 0.7447212942406423, 0.8348185066787255, 2000]

# %%
print('Iteration %i done! S: %f T: %f' % (j,max_score, time_0s))
pp.pprint(max_params)
# Out:
# Iteration 0 done! S: 67.392000 T: 1558227853.376808
# [   0.013789482254543675,
#     32,
#     1.1827441119418947,
#     0.010043847676676102,
#     0.7447212942406423,
#     0.8348185066787255,
#     2000]
